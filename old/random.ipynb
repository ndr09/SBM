# %%
import torch

tensor = torch.tensor([0.7, 0.6, 0.5, 0.4, 0.2, 0.1])
print(tensor)

softmax = torch.nn.Softmax(dim=0)
s = softmax(tensor / 0.1)
print(s)
# Out:
# tensor([0.7000, 0.6000, 0.5000, 0.4000, 0.2000, 0.1000])
# tensor([0.6401, 0.2355, 0.0866, 0.0319, 0.0043, 0.0016])

# %%
# create a matrix
mat = torch.randn((10, 784))
# calculate dft
dft = [torch.fft.fft2(mat[i].view(28, 28)) for i in range(10)]

# plt the dft
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2, 5, figsize=(12, 6))

for i in range(10):
    axs[i//5, i%5].imshow(mt[i]mat[i].view(28, 28))
    axs[i//5, i%5].set_title(f'Image {i+1}')
    axs[i//5, i%5].axis('off')

plt.tight_layout()
plt.show()
